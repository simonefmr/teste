# %% [markdown]
# <a href="https://colab.research.google.com/github/simonefmr/datascience_mvp/blob/main/SCR_MVP1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SCR_MVP**
#
# O objetivo deste projeto é avaliar a evolução do endividamento das pessoas físicas no Brasil, no ano de 2022, conforme registro feito pelas instituições financeiras e comunicados ao Banco Central através do Sistema de Informações de Créditos (SCR).

# %%
# Exemplo de substituição
# Dataframe["coluna"] = 
# Dataframe["coluna"].str.replace(",",".")

# %%
# Importação de pacotes
import pandas as pd
import os
import glob
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests
from sklearn.preprocessing import MinMaxScaler # normalização
from sklearn.preprocessing import StandardScaler # padronização
from sklearn.preprocessing import OrdinalEncoder # ordinal encoding
from sklearn.preprocessing import OneHotEncoder # one-hot encoding e dummy encoding

# %%
pd.__version__
# Out:
# '1.4.4'

# %%
# Importação de dados
# Lê o arquivo

url_2022_01 = 'https://github.com/simonefmr/datascience_mvp/blob/main/database_202201.csv?raw=true'
url_2022_02 = 'https://github.com/simonefmr/datascience_mvp/blob/main/database_202202.csv?raw=true'
url_2022_03 = 'https://github.com/simonefmr/datascience_mvp/blob/main/database_202203.csv?raw=true'
url_2022_04 = 'https://github.com/simonefmr/datascience_mvp/blob/main/database_202204.csv?raw=true'
url_2022_05 = 'https://github.com/simonefmr/datascience_mvp/blob/main/database_202205.csv?raw=true'
url_2022_06 = 'https://github.com/simonefmr/datascience_mvp/blob/main/database_202206.csv?raw=true'
url_2022_07 = 'https://github.com/simonefmr/datascience_mvp/blob/main/database_202207.csv?raw=true'
url_2022_08 = 'https://github.com/simonefmr/datascience_mvp/blob/main/database_202208.csv?raw=true'
url_2022_09 = 'https://github.com/simonefmr/datascience_mvp/blob/main/database_202209.csv?raw=true'
url_2022_10 = 'https://github.com/simonefmr/datascience_mvp/blob/main/database_202210.csv?raw=true'
url_2022_11 = 'https://github.com/simonefmr/datascience_mvp/blob/main/database_202211.csv?raw=true'
url_2022_12 = 'https://github.com/simonefmr/datascience_mvp/blob/main/database_202212.csv?raw=true'

# %%
df_2022_01 = pd.read_csv(url_2022_01, sep=';')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-44-59caff5760e1> in <cell line: 1>()
# ----> 1 df_2022_01 = pd.read_csv(url_2022_01, sep=';')
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
colunas = ['data_base', 'uf', 'tcb', 'sr', 'cliente', 'ocupacao', 'cnae_secao','cnae_subclasse', 'porte', 'modalidade', 'origem', 'indexador', 'numero_de_operacoes', 'a_vencer_ate_90_dias', 'a_vencer_de_91_ate_360_dias', 'a_vencer_de_361_ate_1080_dias', 'a_vencer_de_1081_ate_1800_dias', 'a_vencer_de_1801_ate_5400_dias', 'a_vencer_acima_de_5400_dias', 'vencido_acima_de_15_dias', 'carteira_ativa', 'carteira_inadimplida_arrastada', 'ativo_problematico']

# %%
dataset = pd.read_csv(url, sep=';')

# %%
dataset.shape
# Out:
# (34180, 23)

# %%
dataset.head(10)
# Out:
#     data_base  uf       tcb  sr cliente                     ocupacao  \
# 0  31/01/2022  AC  Bancário  S1      PF  PF - Aposentado/pensionista
# 1  31/01/2022  AC  Bancário  S1      PF  PF - Aposentado/pensionista
# 2  31/01/2022  AC  Bancário  S1      PF  PF - Aposentado/pensionista
# 3  31/01/2022  AC  Bancário  S1      PF  PF - Aposentado/pensionista
# 4  31/01/2022  AC  Bancário  S1      PF  PF - Aposentado/pensionista
# 5  31/01/2022  AC  Bancário  S1      PF  PF - Aposentado/pensionista
# 6  31/01/2022  AC  Bancário  S1      PF  PF - Aposentado/pensionista
# 7  31/01/2022  AC  Bancário  S1      PF  PF - Aposentado/pensionista
# 8  31/01/2022  AC  Bancário  S1      PF  PF - Aposentado/pensionista
# 9  31/01/2022  AC  Bancário  S1      PF  PF - Aposentado/pensionista
#
#   cnae_secao cnae_subclasse                                          porte  \
# 0          -              -  PF - Acima de 20 salários mínimos
# 1          -              -  PF - Acima de 20 salários mínimos
# ...

# %%
pd.DataFrame(dataset.dtypes, columns = ['Tipos de Dados'])
# Out:
#                                Tipos de Dados
# data_base                              object
# uf                                     object
# tcb                                    object
# sr                                     object
# cliente                                object
# ocupacao                               object
# cnae_secao                             object
# cnae_subclasse                        float64
# porte                                 float64
# modalidade                            float64
# origem                                float64
# indexador                             float64
# numero_de_operacoes                   float64
# a_vencer_ate_90_dias                  float64
# a_vencer_de_91_ate_360_dias           float64
# a_vencer_de_361_ate_1080_dias         float64
# a_vencer_de_1081_ate_1800_dias        float64
# a_vencer_de_1801_ate_5400_dias        float64
# a_vencer_acima_de_5400_dias           float64
# ...
